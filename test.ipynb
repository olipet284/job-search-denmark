# %%
import requests

# %%
num_jobs = 25
km_dist = 75
title = "Data Scientist"
postal = 8000

# %%
list_url = f"https://jobnet.dk/bff/FindJob/Search?resultsPerPage={num_jobs}&pageNumber=1&orderType=PublicationDate&kmRadius={km_dist}&searchString={title.replace(' ', '+')}&postalCode={postal}"
response = requests.get(list_url)
if response.status_code != 200:
    print("Error fetching job listings")

# %%
response_dict = response.json()
postings = response_dict.get("jobAds", [])

# %%
# Out:
# [{'country': 'Danmark',
#   'municipality': 'Aarhus',
#   'postalCode': 8000,
#   'postalDistrictName': 'Aarhus C',
#   'hiringOrgName': 'Formalize ApS',
#   'occupation': 'IT-ingeniør',
#   'conceptUriDa': 'http://data.star.dk/esco/occupation/93c9c217-48a0-4e70-9f1e-01a859665578',
#   'workHourPartTime': False,
#   'jobAdId': 'f1232997-860f-402a-bf2c-2ff5fd907722',
#   'jobAdUrl': '',
#   'workPlaceAddress': '',
#   'cvr': '42045136',
#   'title': 'Staff Software Engineer',
#   'description': "Are you looking for a big opportunity and want to invest heavily in your career while being a part of scaling a technical organisation? If so, keep on reading! We are looking for a Staff Software Engineer for our growing Product team.<br><br><strong>The opportunity and what we offer</strong><br><br>Formalize is on a scaling journey with significant traction across Europe. As our new Staff Software Engineer, you'll have the opportunity to learn, grow, and tackle significant problems to make a meaningful impact in our Product and Development team. Seize this distinctive chance to contribute to shaping Formalize's products growth narrative.<br><br><ul><li>Be part of a fast-growing international SaaS company</li><li>High level of trust</li><li>Be part of a social, diverse, and international team</li></ul><br><br>This role starts at 79,000 DKK/month. From there, you’ll be part of our structured career development program, which includes regular performance reviews. As you build skills, take on new responsibilities, and progress in your role, your salary grows with you. Our framework makes development clear and transparent, so you always know what the next step looks like.<br><br><strong>Responsibilities:</strong><br><br><ul><li>Build maintainable, flexible software solutions grounded in core domain-driven design principles—designed to scale alongside the team</li><li>Help shape and drive technical roadmaps, ensuring alignment with broader business goals</li><li>Influence high-level design and architectural decisions that span across multiple teams and projects</li><li>Own projects end-to-end, navigating and solving complex problems along the way</li><li>Maintain a strong business perspective, ensuring engineering decisions support long-term strategic objectives</li><li>Contribute to and support multiple teams through technical complexity, contributing to a unified, forward-looking roadmap</li><li>Mentor senior engineers and serve as a trusted sparring partner—raising the technical bar beyond your immediate team</li><li>Act in a positive way, empowering others to achieve greater impact</li><li>Foster seamless collaboration between product and engineering, driving shared ownership and momentum</li></ul><br><br><strong>Qualifications and about you:</strong><br><br>Professional:<br><br><ul><li>Have a strong grasp of fundamentals and deep knowledge within them; object-oriented programming, common design patterns, system design &amp; testing methodologies</li><li>Tried and tested different approaches to software, and have seen the pros and cons</li><li>Broad knowledge and knowhow of what it takes to build software that is prepared for rapid development</li><li><br></li></ul><br>One or more server-side languages. We primarily use PHP (a few services written in Typescript), and know you are capable of learning a new language<br><br><ul><li>One or more frontend frameworks, including an understand of what complex state-management means and how to handle this in growing applications. We use Angular</li><li>Good testing practices and familiarity with one or more testing frameworks (Vitest, Pest)</li></ul><br><br>Personal:<br><br><ul><li>Pride yourself on how to mentor and influence those around you</li><li>Are curious by nature and keep up to date with modern innovations in the space</li><li>Are able to receive and provide relevant and honest feedback</li><li>Are the go-to person for solving complex problems</li><li>Proactively suggest changes to existing way of working, and never afraid to question fundamentals</li></ul><br><br><strong>Our tech-stack includes:</strong><br><br><ul><li>Angular, including RxJS and observables</li><li>Declarative programming principles</li><li>Global state-management through NgRx</li><li>TailwindCSS for styling</li><li>PostgreSQL and general relational database principles</li><li>PHP and Laravel</li><li>Caching mechanisms through Redis</li><li>Considerations for deploying to a serverless infrast ...
#   'hasLogo': False,
#   'applicationDeadline': '2025-12-12T00:00:00+01:00',
#   'applicationDeadlineStatus': 'ExpirationDate',
#   'isSeen': False,
#   'isFavorite': False,
#   'publicationDate': '2025-10-17T00:00:00+02:00'},
#  {'country': 'Danmark',
#   'municipality': 'Aarhus',
#   'postalCode': 8000,
#   'postalDistrictName': 'Aarhus C',
#   'hiringOrgName': 'FORENINGEN BANKDATA.',
#   'occupation': 'Datalog',
#   'conceptUriDa': 'http://data.star.dk/esco/occupation/12a6a59b-7a4e-4e2e-99d4-2d6c2dfd7bf8',
#   'workHourPartTime': False,
#   'jobAdId': 'E10783101',
#   'jobAdUrl': 'https://bankdata.teamtailor.com/jobs/6606981-test-coordinator',
#   'workPlaceAddress': '',
#   'cvr': '68964415',
#   'title': 'Test Coordinator - Bankdata',
#   'description': 'Test Coordinator - Bankdata\n\n    \n\n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n\n\n\n    \n    \n    \n    \n    \n    \n    \n        \n        \n        \n\n        \n        \n        \n        \n      \n    \n    \n\n    \n  \n\n    \n\n  \n\n\n  \n\n\n\n\n  \n    \n    \n\n      \n\n    \n\n      Dette websted anvender cookies for at sikre, at du får den bedste oplevelse.\n      \n\n        Bankdata og vores udvalgte partnere benytter cookies og lignende teknologier (samlet kaldet “cookies"), som er nødvendige for at præsentere dette websted og sikre, at du får den bedste oplevelse på det.\n\n          Hvis du giver samtykke til det, vil vi også benytte cookies til analyse og markedsføringsformål.\n      \n\n\n      \nSe vores cookiepolitik for at få mere at vide om de cookies, vi benytter.\n\n      \nDu kan til enhver tid trække dit samtykke tilbage og administrere det ved at klikke på "Administrer cookies" nederst på hver webside.\n\n\n\n    \n\n      Accepter alle cookies\n\n        Afvis alle ikke-nødvendige cookies\n\n      Cookie-præferencer\n    \n\n\n      \n  \n\n    Vælg hvilke cookies, du accepterer\n    \nPå dette websted vil vi altid benytte cookies, som er strengt nødvendige, hvilket betyder, at de er nødvendige, for at webstedet kan fungere ordentligt.\n\n    \nHvis du giver samtykke til det, vil vi også benytte andre former for cookies. Du kan give eller tilbagetrække dit samtykke til forskellige former for cookies ved hjælp af valgmulighederne nedenfor. Du kan når som helst ændre dit samtykke, eller trække det tilbage, ved at klikke på “Administrer cookies"-linket, som altid kan findes nederst på webstedet.\n\n    \nFå mere at vide om, hvad de forskellige former for cookies gør, hvordan dine data benyttes, når de indstilles, osv. i vores cookiepolitik.\n\n  \n\n\n  \n\n    \n\n  \n\n    \n    \n\n\n\n\n  \n\n    Strengt nødvendige\n    \nDisse cookies er nødvendige for at få hjemmesiden til at fungere ordentligt og bliver altid indstillet, når du besøger webstedet.\n\n\n      \n        Leverandører\n        Teamtailor\n      \n\n\n\n    \n\n  \n\n    \n    \n\n\n\n\n  \n\n    Analyser\n    \nDisse cookies samler oplysninger, som hjælper os med at forstå, hvordan hjemmesiden bliver brugt.\n\n\n      \n        Leverandører\n        Teamtailor\n      \n\n\n\n    \n    \n\n  \n\n    \n    \n\n\n\n\n  \n\n    Marketing\n    \nDisse cookies benyttes for at skabe reklamebeskeder, som er mere relevante for dig. I nogle tilfælde vil de også levere yderligere funktioner på hjemmesiden.\n\n\n      \n        Leverandører\n        Linkedin\n      \n\n\n\n  \n\n\n  \n\n    Accepter disse cookies\n    Afvis alle ikke-nødvendige cookies\n  \n\n\n\n\n\n    \n\n\n  \n    \n\n  \n\n            \n\n  \n    \n        \n        \n        \n        \n    \n    Karrieremenu\n  \n  \n\n    \n      \n          \n\n            Job\n\n      \n    \n    \n\n      Medarbejder\n      Log ind\n        Kandidat\n        Log ind på Connect\n        Hjemmeside\n        bankdata.dk\n\n  \n\n\n\n\n\n\n\n\n        \n\n    \n\n\n\n\n  \n\n            \n\n  \n\n\n\n  \n          \n\n\n\n  \n\n\n        \n                \n        \n\n        Facebook\n      \n\n        \n                \n        \n\n        X\n      \n\n        \n                \n        \n\n        LinkedIn\n      \n\n\n          \n                    \n          \n\n          Mail\n        \n\n\n\n\n\n\n\n\n\n  \n\n\n\n        \n\n\n    \n\n  \n\n    \n\n      \nInfrastructure, Operations & Security\n\n  ·\n\n    Aarhus\n\n\n    \n\n    Test Coordinator\n    Vær med til at sikre robustheden i den finansielle infrastruktur \n\n      \n\n      \n    \n  \n    \n    Søg her! \n  \n\n\n  \n\n    Vi svarer normalt indenfor 2 uger\n  \n\n\n\n\n\n\n\n  \n\n\n    \n      \n\n\n\n      \n  \n\n    \nVil du være med til at teste, hvor robust fundamentet bag danskernes digitale bankløsninger egentlig er? Som Test Coordinator i Bankdatas Crisis & Conti ...
#   'hasLogo': False,
#   'applicationDeadline': '1910-01-01T00:00:00+01:00',
#   'applicationDeadlineStatus': 'AsSoonAsPossible',
#   'isSeen': False,
#   'isFavorite': False,
#   'publicationDate': '2025-10-15T00:00:00+02:00'},
#  {'country': 'Danmark',
#   'municipality': 'Viborg',
#   'postalCode': 8850,
#   'postalDistrictName': 'Bjerringbro',
#   'hiringOrgName': 'Grundfos A/S',
#   'occupation': 'Programmør og systemudvikler',
#   'conceptUriDa': 'http://data.star.dk/esco/occupation/8b6456a3-ae9a-45a0-a65b-fed797521753',
#   'workHourPartTime': False,
#   'jobAdId': 'E10777473',
#   'jobAdUrl': 'https://jobs.grundfos.com/job/Senior-Software-Engineer/74878-en_GB',
#   'workPlaceAddress': 'Birkevænget 2 10',
#   'cvr': '37499919',
#   'title': 'Senior Software Engineer',
#   'description': 'Research & Development\n     \n                 \n\n             \n\n         \n\n     \n\n    \n \n        \n \n            \n \n                \n \n\n     Senior Software Engineer\n     \n                 \n\n             \n\n         \n\n     \n\n        \n\n        \n\n    \n \n        \n  \n \n\n   \n\n \n \n         \n\n     \n\n            \n  \n\n         \n\n        \n        \n \n            \n \n                \n \n                    \n \n                                        \n \n                                             Job Description \n    \n \n        \n \n            \n \n                \n \n\n     \n  Are you looking for a dynamic work environment to collaborate on IoT data, algorithms, and software development? Then join our innovative and fast-paced team in Grundfos, where we prioritize creating value from our data and revolutionizing the water industry. At the same time, we strive to make a positive and sustainable impact on the world.  \n\n\n   \n\n\n  What is the job about?  \n\n\n  You’ll be responsible for developing, implementing, and maintaining high-quality data products that offer value to our customers based on data insights.  This role also involves collaborating with stakeholders to discuss and scope activities and translate them into technical requirements. Additionally, you’ll challenge and contribute to our standards while collaborating with your colleagues to help them overcome challenges. In this fast-paced environment, you’ll be part of a continuous learning journey, where you’ll discover new things every day.  \n\n\n   \n\n\n  Your main responsibilities:  \n\n \n\n  As a senior software engineer in our Data team, your responsibilities would be:  \n\n\n  Creating, implementing, and maintaining high-quality data products.  \n\n\n  Contributing to a high standard of documentation and to the development process.  \n\n\n  Identifying and solving complex problems using data insights and leveraging both Grundfos’ knowledge in the field but also new technologies.  \n\n\n  Collaborating with different teams involved in the product development to clarify technical requirements.  \n\n \n\n   \n\n\n  What we expect from you:  \n\n \n\n   A master’s degree in computer science, software engineering, electrical engineering, mechanical engineering (or similar field).  \n\n\n  2 to 5 years of experience working with data (data scientist, data engineer), software development, engineering or another relevant topic.  \n\n\n  Experience using version control, namely Git.  \n\n\n  Solid experience working with Python and developing Python applications.  \n\n\n  Some understanding of topics such as signal processing, condition monitoring, optimization, statistics and machine learning.  \n\n\n  Willingness to learn and step out of one’s comfort zone.  \n\n \n\n   \n\n\n   What would be beneficial:  \n\n \n\n  Knowledge of Azure DevOps would be beneficial.  \n\n\n  Experience or knowledge with another language like shell/bash, C, C++, Rust or Go would be a plus.  \n\n\n  Some experience with IoT systems.  \n\n \n\n     \n\n\n  What’s in it for you?  \n\n\n  Whether it’s developing leadership skills or advancing your expertise even further, we’ll support you with continuous learning and development opportunities, to help discuss and steer your long-term Grundfos career path. You’ll be welcomed from day one into an inclusive, trusting environment guided by six core values.  \n\n\n   \n\n\n  In addition, your day-to-day benefits include:  \n\n \n\n  We encourage you to be at the offices, where you can engage, learn, and have fun with colleagues. If you’ll be working from your home office, we’ll make sure you are well equipped with a good workstation  \n\n\n  On top of it, flexible working hours and up to 3 days’ additional paid leave for volunteering of your choice  \n\n\n  Annual bonuses, health insurance, parental support, internal well-being consultants and programmes  \n\n\n  Access to ...
#   'hasLogo': False,
#   'applicationDeadline': '1900-01-01T00:00:00+01:00',
#   'applicationDeadlineStatus': 'NotDisclosed',
#   'isSeen': False,
#   'isFavorite': False,
#   'publicationDate': '2025-10-11T00:00:00+02:00'},
#  {'country': 'Danmark',
#   'municipality': 'Billund',
#   'postalCode': 7190,
#   'postalDistrictName': 'Billund',
#   'hiringOrgName': 'LEGO A/S',
#   'occupation': 'Datalog',
#   'conceptUriDa': 'http://data.star.dk/esco/occupation/12a6a59b-7a4e-4e2e-99d4-2d6c2dfd7bf8',
#   'workHourPartTime': False,
#   'jobAdId': 'E10773801',
#   'jobAdUrl': 'https://www.lego.com/da-dk/careers/job/data-scientist-demand-forecasting-aa877c6e6a971000d741673a54240000',
#   'workPlaceAddress': 'Åstvej 1',
#   'cvr': '54562519',
#   'title': 'Data Scientist - Demand Forecasting - Careers - LEGO.com',
#   'description': "Data Scientist - Demand Forecasting  \n \n\n \n \n \n \n \n Share on: \n \n     \n\n     \n  \n\n  Apply now   \n \n \n \n \n \n \n \n \n  \n \n\n \n  \n  \n Locations \n  \n Billund, Denmark \n\n London, United Kingdom \n    \n\n  \n Job ID \n 0000028751   \n\n  \n Category \n Data & Analytics   \n  \n \n \n \n\n \n \n \n \n   \n \n\n \n \n Job Description \n\n #LI-KO1 \n\n  \n\n We are the Demand Forecasting team at the LEGO Group — a team of 10+ data scientists and engineers with specialization in Machine Learning (ML) and MLOps. We deliver statistical and ML forecasts that enhance decision-making in the demand planning process at the LEGO Group. Think of predicting sales for a LEGO set one year from now, across all global markets. How does that challenge sound to you? \n Core Responsibilities \n We are seeking a skilled Data Scientist with hands-on forecasting expertise to join our Demand Forecasting team. This role requires strong technical capability in time series and machine learning models, combined with the ability to translate data insights into clear business narratives that drive decision-making. \n\n You will spend approximately 50% of your time on operational forecast delivery and 50% on improving accuracy, analysing results, and innovating. \n Play your part in our team succeeding:  \n Deliver operational forecasts: Contribute to the continuous production and monitoring of forecasts used by LEGO demand planners worldwide, ensuring stability and reliability in operations. \n\n Improve forecasting models: Design, test and implement enhancements to time series and ML models, including in-depth understanding of algorithm fundamentals and parameters, to increase accuracy and adoption. \n\n Engage with collaborators: Partner with demand planners and other business collaborators to increase forecast adoption and enable data-driven decision-making. \n\n Analyse and interpret forecast performance: Identify patterns in data, evaluate results, and provide clear narratives on drivers, outcomes, and business implications. \n\n Bridge business and data science: Act as a translator between technical outputs and business needs, ensuring partners understand and trust forecasts. \n\n Contribute to scalable solutions: Support the development and deployment of forecasting workflows in production within Databricks. \n  Do you have what it takes?  \n Minimum 3 years of experience in forecasting, with direct application of time series and ML models. \n\n Proficiency in Python, SQL, and Databricks \n\n Demonstrated ability to translate technical analyses into business-relevant insights through clear communication and data storytelling. \n\n Experience balancing continuous operational delivery with model innovation and improvement. \n\n Strong analytical outlook with attention to detail and data quality. \n  Nice to have  \n Background in supply chain, retail, planning or other forecasting environments. \n\n Experience with MLOps practices and scalable model deployment. \n\n Experience with Pyspark   \n \n  \n\n Applications are reviewed on an ongoing basis. However, please note we do amend or withdraw our jobs and reserve the right to do so at any time, including prior to any advertised closing date. So, if you're interested in this role we encourage you to apply as soon as possible.",
#   'hasLogo': False,
#   'applicationDeadline': '1910-01-01T00:00:00+01:00',
#   'applicationDeadlineStatus': 'AsSoonAsPossible',
#   'isSeen': False,
#   'isFavorite': False,
#   'publicationDate': '2025-10-09T00:00:00+02:00'},
#  {'country': 'Danmark',
#   'municipality': 'Silkeborg',
#   'postalCode': 8600,
#   'postalDistrictName': 'Silkeborg',
#   'hiringOrgName': 'Birch Byg Holding ApS',
#   'occupation': 'Digitaliseringskonsulent',
#   'conceptUriDa': 'http://data.star.dk/esco/occupation/c6447aff-e6a5-47a1-abc1-c2babe185f63',
#   'workHourPartTime': False,
#   'jobAdId': 'bcfc8104-b4a1-410b-b434-f207ed4b0026',
#   'jobAdUrl': '',
#   'workPlaceAddress': '',
#   'cvr': '39580349',
#   'title': 'AI Lead med ansvar for AI-implementering – Bliv nøgleperson i Birch Ejendommes AI-rejse',
#   'description': '<p><strong>Er du passioneret omkring kunstig intelligens og datadrevne løsninger – og trives du med at tage ejerskab, skabe overblik og få ting til at ske i samarbejde med både forretning og IT? Så har du nu en unik mulighed for at blive frontløber i Birch Ejendommes AI-indsats.</strong></p><p><strong>Vi søger en kompetent og initiativrig AI Business Lead eller Data Scientist til en nyoprettet stilling, hvor du bliver ansvarlig for at drive og udvikle vores brug af AI – fra identifikation af AI-muligheder på tværs af vores værdikæde til udvælgelse og implementering af AI-usecases. Du får en unik mulighed&nbsp;for at være med til at sætte&nbsp;retningen og mulighed for at præge både strategi og konkrete løsninger.</strong></p><p></p><p><strong>Om jobbet</strong></p><p>Vi står i opstartsfasen med at integrere AI i vores forretning – og vi har brug for en kollega, som kan tage førertrøjen på og bygge bro mellem forretningens behov og de teknologiske muligheder.</p><p>Som vores nye AI Business Lead / Data Scientist bliver du ansvarlig for at:</p><ul><li><p>Identificere og prioritere områder på tværs af hele vores værdikæde, hvor AI og automatisering kan skabe forretningsmæssig værdi</p></li><li><p>Validere eksisterende workflows, afholde workshops med forretningen, udarbejde value/effort-matrix og et roadmap over værdiskabende AI-usecases</p></li><li><p>Drive og lede AI-projekter fra idé og konceptudvikling til implementering og evaluering – i samarbejde med vores AI-ambassadører og øvrige kolleger i forretningen</p></li><li><p>Udvikle mindre prototyper og POC’er (fx chatbots, simple modeller, automatiseringer)</p></li><li><p>Være bindeled mellem ledelse, fagområder og tekniske samarbejdspartnere</p></li><li><p>Sikre fremdrift, struktur og kvalitet i hele AI-sporet</p></li></ul><p>Du bliver en del af et tværfagligt miljø, hvor vi arbejder agilt, og hvor dine input og initiativer bliver værdsat. Vi forventer ikke, at du kan alt fra dag ét – men du skal kunne drive opgaven og trives med ansvar.</p><p>&nbsp;</p><p><strong>Om dig</strong></p><p>Vi leder efter en profil, der kombinerer teknisk forståelse, projektledelse og forretningssans. Du har nogle års erfaring med datadrevne løsninger og AI – og har mod på at gå forrest i en ny strategisk satsning.</p><p>Vi forestiller os, at du har:</p><ul><li><p>En videregående uddannelse inden for data science, datalogi, AI, machine learning eller lignende</p></li><li><p>Ca. 3–5 års relevant erfaring – fx fra konsulentbranchen, en tech-virksomhed eller en intern data science-afdeling</p></li><li><p>Praktisk erfaring med dataanalyse, AI-strategi, ML-modeller, Python og relevante AI-værktøjer</p></li><li><p>Erfaring med at omsætte forretningsbehov til datadrevne løsninger</p></li><li><p>Evne til at forklare komplekse emner på en forståelig og værdiskabende måde</p></li><li><p>Stærke projektledelses- og samarbejdsevner – du kan både drive, koordinere og eksekvere</p></li><li><p>Interesse for både teknologi, processer og forretningens udvikling</p></li></ul><p>Det er en fordel, hvis du har arbejdet med udvikling af prototyper, chatbots eller lignende AI-løsninger – men det vigtigste er din evne til at skabe resultater i krydsfeltet mellem data og forretning.</p><p></p><p><strong>Vi glæder os til at tilbyde dig</strong></p><ul><li><p>Tværfagligt samarbejde samt intern sparring med dine dygtige kolleger</p></li><li><p>En arbejdsplads, hvor vi hjælper hinanden og prioriterer trivsel højt</p></li><li><p>En arbejdsdag med spændende og varierende opgaver, hvor du både kan anvende og udvide din faglige viden</p></li><li><p>Et balanceret arbejdsliv med fleksible arbejdstider</p></li><li><p>Gode vilkår og personalegoder, herunder fritvalgsopsparing, pension, sundhedsforsikring og massageordning</p></li><li><p>Sund og lækker kantineordning</p></li><li><p>Base på vores kontor i Silkeborg, med en beliggenhed kun fem minutters kørsel fra motorvejen</p></li><li><p>Fast fuldtidsstilling med tilt ...
#   'hasLogo': False,
#   'applicationDeadline': '2025-12-01T00:00:00+01:00',
#   'applicationDeadlineStatus': 'ExpirationDate',
#   'isSeen': False,
#   'isFavorite': False,
#   'publicationDate': '2025-10-06T00:00:00+02:00'},
#  {'country': 'Danmark',
#   'municipality': 'Aarhus',
#   'postalCode': 8000,
#   'postalDistrictName': 'Aarhus C',
#   'hiringOrgName': 'S360 A/S',
#   'occupation': 'Datalog',
#   'conceptUriDa': 'http://data.star.dk/esco/occupation/12a6a59b-7a4e-4e2e-99d4-2d6c2dfd7bf8',
#   'workHourPartTime': False,
#   'jobAdId': 'E10769270',
#   'jobAdUrl': 'https://jobs.s360digital.com/jobs/6562392-data-scientist-marketing-mix-modeling-mmm',
#   'workPlaceAddress': 'Mariane Thomsens Gade 2 4',
#   'cvr': '34052697',
#   'title': 'Data Scientist, Marketing Mix Modeling (MMM) - s360',
#   'description': 'Data Scientist, Marketing Mix Modeling (MMM) - s360\n\n    \n\n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n\n\n\n    \n    \n    \n    \n    \n    \n    \n        \n        \n        \n\n        \n        \n        \n        \n      \n    \n    \n\n    \n  \n\n    \n\n  \n\n\n  \n\n  \n    \n    \n\n      \n\n    \n\n      This website uses cookies to ensure you get the best experience.\n      \n\n        s360 and our selected partners use cookies and similar technologies (together “cookies") that are necessary to present this website, and to ensure you get the best experience of it.\n\n          If you consent to it, we will also use cookies for analytics and marketing purposes.\n      \n\n\n      \nSee our Cookie Policy to read more about the cookies we set.\n\n      \nYou can withdraw and manage your consent at any time, by clicking “Manage cookies" at the bottom of each website page.\n\n\n\n    \n\n      Accept all cookies\n\n        Decline all non-necessary cookies\n\n      Cookie preferences\n    \n\n\n      \n  \n\n    Select which cookies you accept\n    \nOn this site, we always set cookies that are strictly necessary, meaning they are necessary for the site to function properly.\n\n    \nIf you consent to it, we will also set other types of cookies. You can provide or withdraw your consent to the different types of cookies using the toggles below. You can change or withdraw your consent at any time, by clicking the link “Manage Cookies", which is always available at the bottom of the site.\n\n    \nTo learn more about what the different types of cookies do, how your data is used when they are set etc, see our Cookie Policy.\n\n  \n\n\n  \n\n    \n\n  \n\n    \n    \n\n\n\n\n  \n\n    Strictly necessary\n    \nThese cookies are necessary to make the site work properly, and are always set when you visit the site.\n\n\n      \n        Vendors\n        Teamtailor\n      \n\n\n\n    \n\n  \n\n    \n    \n\n\n\n\n  \n\n    Analytics\n    \nThese cookies collect information to help us understand how the site is being used.\n\n\n      \n        Vendors\n        Teamtailor\n      \n\n\n\n    \n    \n\n  \n\n    \n    \n\n\n\n\n  \n\n    Marketing\n    \nThese cookies are used to make advertising messages more relevant to you. In some cases, they also deliver additional functions on the site.\n\n\n      \n        Vendors\n        Meta, Linkedin\n      \n\n\n\n  \n\n\n  \n\n    Accept these cookies\n    Decline all non-necessary cookies\n  \n\n\n\n\n\n    \n\n\n  \n    \n\n  \n\n            \n\n  \n    \n        \n        \n        \n        \n    \n    Career menu\n  \n  \n\n    \n      \n    \n    \n\n  \n\n\n\n\n\n\n\n\n\n  \n\n            \n\n  \n\n\n\n  \n          \n\n\n  \n\n\n\n\n\n  \n\n\n\n        \n\n\n    \n\n  \n\n    \n\n      \nCloud\n\n  ·\n\n    Multiple locations\n\n\n    \n\n    Data Scientist, Marketing Mix Modeling (MMM)\n    \n\n      \n\n      \n    \n  \n    \n    Apply here \n  \n\n\n\n\n\n\n\n\n  \n\n\n    \n      \n\n\n      \n  \n\n    \nAre you driven by the challenge of designing and operationalizing statistically rigorous models that directly quantify business impact? Are you an expert in statistical inference and Bayesian methodologies, capable of moving beyond correlation to establish causality?\n\nWe are seeking a talented and experienced Data Scientist with a special focus on Marketing Mix Modeling (MMM) to join our growing team. s360 is a leading digital marketing agency and a certified Google Meridian partner. We\'re rapidly expanding our data science and cloud capabilities, particularly in Marketing Mix Modeling (MMM), to deliver cutting-edge solutions that drive marketing effectiveness for our clients.\n\n\n\nLead the marketing modeling transformation\n\nYou will play an instrumental role in developing and implementing advanced MMM solutions, directly helping our clients understand and optimize their marketing investments.\n\nAs a Data Scientist for MMM at s3 ...
#   'hasLogo': False,
#   'applicationDeadline': '1910-01-01T00:00:00+01:00',
#   'applicationDeadlineStatus': 'AsSoonAsPossible',
#   'isSeen': False,
#   'isFavorite': False,
#   'publicationDate': '2025-10-04T00:00:00+02:00'},
#  {'country': 'Danmark',
#   'municipality': 'Hedensted',
#   'postalCode': 8722,
#   'postalDistrictName': 'Hedensted',
#   'hiringOrgName': 'Hedensted Kommune',
#   'occupation': 'Politolog',
#   'conceptUriDa': 'http://data.star.dk/esco/occupation/3ce1b2fd-d161-4233-8a56-3590401490d0',
#   'workHourPartTime': False,
#   'jobAdId': 'deacfd83-8b66-4338-a704-2f0c40c72809',
#   'jobAdUrl': '',
#   'workPlaceAddress': '',
#   'cvr': '29189587',
#   'title': 'AC-fuldmægtig søges til etårigt barselsvikariat i Politik & Udvikling',
#   'description': '<p><strong>I en spændende periode præget af politiske reformer, valgår og onboarding af en ny Kommunalbestyrelse, tilbyder vi et barselsvikariat fyldt med muligheder som AC-fuldmægtig i Politik &amp; Udvikling i Hedensted Kommune. Her får du en unik chance for at arbejde tæt på den nye Kommunalbestyrelse, kommunaldirektøren og direktionen, med opgaver, der understøtter hele organisationen. Vi er en decentral kommune i rivende udvikling med korte beslutningsveje og høje ambitioner. Vi søger derfor en initiativrig kollega, der kan bevare overblikket og være med til at sikre fremdrift i opgaverne. Måske er det dig, vi leder efter?&nbsp;</strong></p><b><strong>Om jobbet og opgaverne</strong></b><br><p>Vi har gang i mange spændende projekter, såsom omsætning af hele seks politiske reformer, valg, modtagelse af en ny Kommunalbestyrelse, to store kompetenceudviklingsforløb for hele organisationen og understøttelse af organisationens ledelse.</p><p>Du skal særligt understøtte det politiske niveau, direktionen, kommunaldirektøren og afdelingens leder med at sikre høj kvalitet i den daglige opgaveløsning, holde overblikket og sikre sammenhæng i de mange og spændende opgaver, der kommer til at lande på dit bord. Vi har fokus på at sikre gode processer og at følge opgaverne til dørs – sammen. Du bliver således en del af en afdeling med 21 engagerede og hjælpsomme kollegaer, hvor du hører til opgavefællesskabet ”Organisationsudvikling”.&nbsp;</p><p>Hos os får du en central rolle med meningsfulde opgaver på tværs af hele organisationen. Dine arbejdsdage vil blandt andet byde på:</p><ul><li><strong>Tæt samarbejde med ledelsen</strong> – du bliver en nøgleperson i betjeningen af Kommunalbestyrelsen, kommunaldirektøren, direktionen og afdelingens leder.</li><li><strong>Løbende opgaveløsning</strong> – du får løbende opgaver ind, som har en meget alsidig karakter og både rækker op og ud i organisationen. Ligesom de kan række fra lavpraktisk, konkret og kortvarig til udviklingsorienteret og længerevarende.&nbsp;</li><li><strong>Initiativrig bidragsyder til projekter og processer&nbsp;</strong>– du får mulighed for og forventes selvstændigt at drive eller bidrage til forskellige projekter og processer, der både rækker op og ud i organisationen.&nbsp;</li><li><strong>Sparringspartner</strong> – du understøtter kommunaldirektøren og afdelingens chef i arbejdet med vigtige dagsordener og udviklingsinitiativer.</li><li><strong>Forberedelse af større ledermøder</strong> – du kommer til at koordinere og forberede møder for kommunens ledelse, herunder tværgående chefmøder og ledermøder.</li><li><strong>Direktionsunderstøttelse med overblik og indsigt</strong> – du bidrager til, at direktionen har det nødvendige beslutningsgrundlag og fremdrift i deres arbejde.</li><li><strong>Opgaver med afsæt i dine styrker</strong> – vi tilpasser dine konkrete opgaver efter dine kompetencer og erfaringer, så du får mulighed for at bringe dine evner i spil – og udvikle dig undervejs.</li></ul><p>Centralt for alle opgaverne er overblik, koordinering og kvalitetssikring samt en stor grad af selvstændighed i opgaveløsningen.</p><b><strong>Vores forventninger til dig</strong></b><br><p>Vi forestiller os, at du:</p><ul><li>Har en relevant akademisk uddannelse på kandidatniveau (dokumentation vedlægges).&nbsp;</li><li>Enten er nyuddannet eller har nogle års erfaring fra en lignende stilling.</li><li>Har stærke koordineringsevner og er handlekraftig – du sikrer fremdrift i opgaver og får tingene til at ske.</li><li>Er en dygtig kommunikator, både skriftligt og mundtligt, og kan formidle komplekst materiale klart og præcist.</li><li>Er nysgerrig og proaktiv. Du tager gerne fat på nye opgaver og fagområder med en åben og løsningsorienteret tilgang.&nbsp;</li><li>Har interesse for – og gerne viden om – kommunale forhold og politisk styrede organisationer.</li><li>Er en imødekommende person, der nemt opbygger gode relationer og samarbejder effektivt med kollegae ...
#   'hasLogo': True,
#   'applicationDeadline': '2025-10-20T21:59:00+02:00',
#   'applicationDeadlineStatus': 'ExpirationDate',
#   'isSeen': False,
#   'isFavorite': False,
#   'publicationDate': '2025-10-02T00:00:00+02:00'},
#  {'country': 'Danmark',
#   'municipality': 'Billund',
#   'postalCode': 7190,
#   'postalDistrictName': 'Billund',
#   'hiringOrgName': 'LEGO A/S',
#   'occupation': 'Datalog',
#   'conceptUriDa': 'http://data.star.dk/esco/occupation/12a6a59b-7a4e-4e2e-99d4-2d6c2dfd7bf8',
#   'workHourPartTime': False,
#   'jobAdId': 'E10764004',
#   'jobAdUrl': 'https://www.lego.com/da-dk/careers/job/data-scientist-machine-learning-engineer-parental-leave-cover-32fc59751e2b100169f99e150e320000',
#   'workPlaceAddress': 'Åstvej 1',
#   'cvr': '54562519',
#   'title': 'Data Scientist / Machine Learning Engineer - Parental Leave Cover - Careers - LEGO.com',
#   'description': "Data Scientist / Machine Learning Engineer - Parental Leave Cover  \n \n\n \n \n \n \n \n Share on: \n \n     \n\n     \n  \n\n  Apply now   \n \n \n \n \n \n \n \n \n  \n \n\n \n  \n  \n Location \n Billund, Denmark   \n\n  \n Job ID \n 0000028425   \n\n  \n Category \n Data & Analytics   \n  \n \n \n \n\n \n \n \n \n \n Job Description \n\n #LI-KO1 \n\n  \n\n Can you drive measurable value through the applied use of data science? Are you passionate about helping us innovate and test out new paths? \n\n This is a temporary hire for approximately 9 months, and we do not offer financial support for relocation for this role. \n Core Responsibilities \n The utilization of Data Science and AI is rapidly growing within the LEGO Group. We use the methodologies to discover deeper insights, make predictions, or generate recommendations to continue delivering world class learning-through play experiences to children. \n\n You will be joining the AI + Data Science Organisation, which is the home of 50 data scientists and engineering colleagues, distributed across our Denmark and UK offices. \n\n You will be reporting into the Assortment & Space Management team which has the purpose of optimizing the assortment for our B2B customers. We are looking for a data scientist who can help build solutions in a production ready setup with a focus on scalability and maintainability. \n\n Your tasks will include: \n \n Develop working and robust machine learning models to solve complex problems. \n\n Build end-to-end ML and AI solutions that can are easy to maintain and scale \n\n Collaborating with partners to ensure that data science work is delivering real value. \n\n Contribute to our ways of working and help establish standard methodologies. \n\n Staying up to date with machine learning developments across the industry. \n  Do you have what it takes? \n We are looking for a candidate with emphasis on one or more of the following: data science, computer science, engineering, mathematics, or an equivalent quantitative subject area. \n\n You have previous experience creating working ML and AI solutions in a large organization and are used to working in an agile cross functional setup and with a broad range of partners. \n \n Proficiency with Python (or similar languages) and its libraries for machine learning such as PySpark, scikit-learn, pandas and pytorch. \n\n Prior experience with general software development practices including code management (Git) and testing. \n\n Collaborative spirit and a playful can-do attitude. \n\n Persistent with a well-rounded view on creating solutions. \n\n Experience with tools and platforms such as Databricks and MLflow for ML training and experimenting is highly desirable. \n \n  \n\n Applications are reviewed on an ongoing basis. However, please note we do amend or withdraw our jobs and reserve the right to do so at any time, including prior to any advertised closing date. So, if you're interested in this role we encourage you to apply as soon as possible.",
#   'hasLogo': False,
#   'applicationDeadline': '1910-01-01T00:00:00+01:00',
#   'applicationDeadlineStatus': 'AsSoonAsPossible',
#   'isSeen': False,
#   'isFavorite': False,
#   'publicationDate': '2025-10-02T00:00:00+02:00'},
#  {'country': 'Danmark',
#   'municipality': 'Aarhus',
#   'postalCode': 8200,
#   'postalDistrictName': 'Aarhus N',
#   'hiringOrgName': 'PEAK Wind ApS',
#   'occupation': 'Datalog',
#   'conceptUriDa': 'http://data.star.dk/esco/occupation/12a6a59b-7a4e-4e2e-99d4-2d6c2dfd7bf8',
#   'workHourPartTime': False,
#   'jobAdId': 'E10765724',
#   'jobAdUrl': 'https://peak-wind.career.emply.com/ad/senior-data-engineer/gqb3t8',
#   'workPlaceAddress': 'Jens Baggesens Vej 90',
#   'cvr': '38529587',
#   'title': 'Senior Data Engineer I Career Site',
#   'description': 'Senior Data Engineer I Career Site\n    \n\n            \n            \n            \n            \n            \n            \n  \n\n\n\n\n\n\n\n    \n\n\n    \n\n\n    \n\n\n\n    \n\n    \n\n    \n\n    \n    \n\n    \n\n    \n\n\n    \n\n    \n\n\n    \n\n\n\n\n\n\n\n\n\n    \n\n\t    \n\n    \t\t\n\n\n    \t\t\n\n\n    \t\n\n    \n\n\n\n                    \n\n\n\n\n\n\n\n    \n\n\n\n\n\n\n\n\t\n\t\n\t\n\n\n\n\n\n\n\t\n\n\t\t\n\n\t\t    \n\n\n\t\t    Senior Data Engineer\n\t\t\t\t\n\n\n\t\t\t\n\nAre you looking for an opportunity to help accelerate the global energy transformation into renewable energy sources? PEAK Wind is looking for a Senior Data Engineer to support our DevOps & Architecture team in building and operating data pipelines and analytics for an ever-growing data flow from various wind farms and solar projects. Join our group of data engineers and developers as we go byte by byte towards a more sustainable future.\n\n \n\nTrusted Advisors for Developers and Investors for Some of the Largest Renewable Assets \nAt PEAK Wind, we specialise in operations, asset management, and project management of renewable energy assets and take pride in providing best-in-class commercial, financial, and operational advisory and support to our clients. We work with some of the world’s largest infrastructure investments and are proud to count market-leading utilities, investment funds, and IPPs among our clients.\n\n \n\nJob Content and Responsibilities\nBased in our office in Copenhagen, you will be part of our DevOps & Architecture team, which is a part of our Data & Intelligence team. This team works within PEAK Wind’s operations management service offering and manages full value chain data management for our clients. You will report to the Head of DevOps & Architecture and work in an agile team of mixed seniorities. The team manages a portfolio of more than 2.5 GW of renewable energy projects worldwide. PEAK Wind is basing its solutions on Microsoft Azure infrastructure.\n\nMore specifically, your areas of responsibility will be:\n\nHelping the team make the best design choices on new data engineering infrastructure\n\nProviding analysis capabilities and data guidance to our stakeholders\n\nDesigning, implementing, and maintaining data processing pipelines\n\nOwning the daily data flows and making sure the data quality remains high\n\nCollaborating with the Product Owner to understand business requirements\n\nDeveloping, implementing, and maintaining metric calculations that bring value to our stakeholders\n\nLearning and exploring new advancements in the fields of renewable energy and data engineering\n\n \n\nWhat you bring and your qualities\nWe are looking for a Senior Data Engineer with a relevant bachelor’s or master’s degree in Data Science, Data Engineering, or Computer Science. Ideally, you have a minimum of 5 years of experience in a similar position in which you have worked with Microsoft Azure (Container Apps, Databases, RBAC, Key Vaults, Virtual Networks, etc.), created high-quality ELT/ETL pipelines, and GitHub. Furthermore, you have programming skills in Python, Javascript, and SQL. Experience within renewable energy projects is an advantage but not a requirement.\n\nAs a person, you have an agile, adaptive mindset and can respond quickly to changes in your working environment. You are proactive and apply a ‘can-do’ approach to the completion of tasks. You are structured, results-driven, and like to find smarter and more efficient ways to solve problems. Furthermore, we expect that you are a team player, who wants to share your knowledge and skills with the team, and you also know how to make others feel part of the team. As PEAK Wind is a global company, you must have strong English communication skills.\n\n \n\nExperience the Highest Degree of Involvement\nPEAK Wind is dedicated to fostering a work environment that values diversity, and our values of Expertise, Passion, Unity, and Integrit ...
#   'hasLogo': False,
#   'applicationDeadline': '2025-10-31T00:00:00+01:00',
#   'applicationDeadlineStatus': 'ExpirationDate',
#   'isSeen': False,
#   'isFavorite': False,
#   'publicationDate': '2025-10-02T00:00:00+02:00'},
#  {'country': 'Danmark',
#   'municipality': 'Aarhus',
#   'postalCode': 8000,
#   'postalDistrictName': 'Aarhus C',
#   'hiringOrgName': 'WasteHero ApS',
#   'occupation': 'IT-ingeniør',
#   'conceptUriDa': 'http://data.star.dk/esco/occupation/93c9c217-48a0-4e70-9f1e-01a859665578',
#   'workHourPartTime': False,
#   'jobAdId': 'b273aa15-545b-4178-92fc-ed000adafc42',
#   'jobAdUrl': '',
#   'workPlaceAddress': '',
#   'cvr': '38796755',
#   'title': 'Lead Backend Engineer – Python (Aarhus HQ, Onsite)',
#   'description': ' Lead Backend Engineer – Python (Aarhus HQ, Onsite)<br><br>Location: Aarhus, Denmark (Onsite, HQ)<br><br>Employment: Full-time<br><br>Salary: Competitive + stock options available<br><br><br><br><br><br><strong>About WasteHero</strong><br><br>At WasteHero, we’re on a mission to revolutionize municipal waste management with cutting-edge, cloud-native software. Our SaaS platform helps cities and private operators optimize routes, automate billing, ensure compliance, and build greener communities.<br><br>We already work with municipalities and waste companies across Europe and the Middle East -and we’re just getting started.<br><br>Backed by institutional investors and public funding, we’re a mission-driven scaleup with strong product-market fit. Our HQ in Aarhus is where product and engineering sit at the heart of the business.<br><br><br><br><br><br><strong>Why This Role is Different</strong><br><br>This is not just another backend role — this is a mission-critical leadership hire at a turning point for WasteHero.<br><br>Our product is undergoing a core redesign to make onboarding, integrations, and migrations faster and simpler. This is your chance to take the technical lead on a high-impact transformation, working closely with our CEO, product leads, and engineers in Aarhus to solve complex problems in hours, not days.<br><br><br><br><br><br><strong>The Role</strong><br><br>As Lead Backend Engineer, you will:<br><br><ul><li>Own the architecture and development of our Python/Django + FastAPI services</li></ul><br><br><ul><li>Lead by example, mentoring developers and enforcing best practices in code quality, security, and maintainability</li></ul><br><br><ul><li>Redesign critical systems to make customer onboarding &lt;2 months (currently 6+)</li></ul><br><br><ul><li>Collaborate closely with product, DevOps, and frontend teams to ship improvements fast</li></ul><br><br><ul><li>Drive architectural decisions for performance, scalability, and fault-tolerance</li></ul><br><br><br><br><strong>Our Tech Stack</strong><br><br><ul><li><strong>Backend</strong>: Python 3, Django, FastAPI</li></ul><br><br><ul><li><strong>Data</strong>: PostgreSQL, Redis, Celery</li></ul><br><br><ul><li><strong>APIs</strong>: GraphQL (Graphene), REST</li></ul><br><br><ul><li><strong>Infra</strong>: Docker, gunicorn, Bitbucket Pipelines (CI/CD)</li></ul><br><br><ul><li><strong>Hosting</strong>: Hetzner (Germany &amp; Finland) – private networking &amp; load balancing</li></ul><br><br><br><br><br><br><strong>You Bring</strong><br><br><ul><li>5+ years backend development experience (Python/Django preferred)</li><li><br></li><li>Proven track record of building and scaling production systems</li><li><br></li><li>Strong experience with relational databases (PostgreSQL or similar)</li></ul><br><br><ul><li>Confidence in Docker, CI/CD, and modern dev pipelines</li></ul><br><br><ul><li>Leadership skills — mentoring, architectural calls, guiding teams</li></ul><br><br><ul><li>Pragmatic mindset focused on security, performance, and clean design</li></ul><br><br><ul><li>Bonus: FastAPI, GraphQL, SaaS platforms, public sector software experience</li></ul><br><br><br><br><br><br><strong>Why Join Us Now?</strong><br><br><ul><li>High-impact leadership role – your work directly shapes WasteHero’s product evolution</li></ul><br><br><ul><li>Onsite collaboration – work daily with decision-makers for rapid iteration</li></ul><br><br><ul><li>Ownership – real autonomy, not just tickets in a backlog</li></ul><br><br><ul><li>Equity potential – grow with us as we scale internationally</li></ul><br><br><ul><li>Purpose-driven mission – use your skills to drive real-world environmental change</li></ul><br><br><br><br> Must be able to work onsite from our Aarhus HQ. Relocation support can be discussed.<br><br><br><br> Apply directly on Thehub: <a href="https://thehub.io/jobs/689827360bda567267a37678?utm_source=linkedin&amp;utm_medium=referral&amp;utm_campaign=xmlfeed">ht ...
#   'hasLogo': False,
#   'applicationDeadline': '2025-11-13T00:00:00+01:00',
#   'applicationDeadlineStatus': 'ExpirationDate',
#   'isSeen': False,
#   'isFavorite': False,
#   'publicationDate': '2025-09-18T00:00:00+02:00'},
#  {'country': 'Danmark',
#   'municipality': 'Aarhus',
#   'postalCode': 8000,
#   'postalDistrictName': 'Aarhus C',
#   'hiringOrgName': 'IBM DANMARK ApS',
#   'occupation': 'Datalog',
#   'conceptUriDa': 'http://data.star.dk/esco/occupation/12a6a59b-7a4e-4e2e-99d4-2d6c2dfd7bf8',
#   'workHourPartTime': False,
#   'jobAdId': 'E10742702',
#   'jobAdUrl': 'https://ibmglobal.avature.net/en_US/careers/JobDetail?jobId=57519&source=WEB_Search_NA',
#   'workPlaceAddress': 'Mariane Thomsens Gade 2 8',
#   'cvr': '65305216',
#   'title': 'Data Engineer Consultant - 57519 - IBM',
# ...
#   'hasLogo': False,
#   'applicationDeadline': '1900-01-01T00:00:00+01:00',
#   'applicationDeadlineStatus': 'NotDisclosed',
#   'isSeen': False,
#   'isFavorite': False,
#   'publicationDate': '2025-09-13T00:00:00+02:00'},
#  {'country': 'Danmark',
#   'municipality': 'Silkeborg',
#   'postalCode': 8600,
#   'postalDistrictName': 'Silkeborg',
#   'hiringOrgName': 'JN Data',
#   'occupation': 'IT-ingeniør',
#   'conceptUriDa': 'http://data.star.dk/esco/occupation/93c9c217-48a0-4e70-9f1e-01a859665578',
#   'workHourPartTime': False,
#   'jobAdId': 'E10738213',
#   'jobAdUrl': 'https://jndata-career.talent-soft.com/job/job-senior-aks-platform-engineer_435.aspx',
#   'workPlaceAddress': '',
#   'cvr': '26404657',
#   'title': 'JN DATA - Senior AKS Platform Engineer',
#   'description': 'JN DATA - Senior AKS Platform Engineer\n\n    \n\n\n\n\n\n\n        \n\n        \n\n        \n\n        \n\n        \n    \n    \n    \n    \n\n    \n\n\n    \n    \n\n\n\n\n\n\n    \n\n        \n\n\n    \n\n    \n\n\n    \n    \n            \n\n            \n\n\n            \n\n \n            \n\n    \n            \n\n                \n                \n                \n                \n                \n                \n\n                    \n                    \n                    \n\n                    \n                    \n                    \n\n                    \n                    \n                    \n\n                    \n                    \n                    \n                \n\n                \n                \n\n                \n                \n                    \n\n                        \n\n                            \n                                \n\n        \n    \n\n\n                            \n\n                            \n                            \n\n                                \n\n\n                            \n\n                            \n\n                            \n                                \n\n                                    \n                                        Følg os\n                                    \n                                    \n                                        \n                                    \n                                \n\n                            \n                        \n\n\n                        \n\n\n                        \n                        \n                        \n                    \n\n\n                    \n\n                        \n                            \n\n        \n\n            Du befinder dig her : \n            \n                \n                \n\n    \n                Startside\n    \n          ›  \n\n    \n                Liste over stillinger\n    \n          ›  \n\n    \n        Stillingsinformationer\n    \n\n                \n            \n        \n\n    \n\n\n                        \n\n                        \n\n\n                    \n\n\n                    \n                    \n\n                        \n\n                            \n                            \n                        \n\n                        \n\n\n                        \n\n                            \n                        \n \n                    \n\n                    \n                \n\n            \n\n            \n\n                \n                    \n\n                        \n\n                        \n\n                            \n                            \n                                Menu \n                                Karrieresite\n                                 JN DATA\n                            \n                            \n\n                        \n\n                        \n                        \n                        \n                        \n                    \n\n                \n                \n\n                    \n\n                    \n\n\n\n\n\n\n\n\n    \n\n        \n        \n            \n                Søgemaskine til stillinger JN DATA\n            \n            \n\n\t\n                \n                \n\n\n                    \n\n\t\t\n\n        \n\n            Stillingens beliggenhed\n        \n\n        \n\n            Ansættelsesform\n        \n\n    \n\n\n\n        \n\n            Stillingsbetegnelse\n        \n\n        \n    \n\n\n\t\n\n\n                    \n\n\n                \n\n            \n\n\n        \n    \n\n\n\n\n                        \n                        \n\n\n\n\n\n                        \n    \n\n                        \n\n\n    \n\n        \n    \n\n    \n\n    \n\n\n\n                        \n                    \n                        \n\n                        \n\n                            \n    \n    \n\n        \n            \n  ...
#   'hasLogo': False,
#   'applicationDeadline': '1900-01-01T00:00:00+01:00',
#   'applicationDeadlineStatus': 'NotDisclosed',
#   'isSeen': False,
#   'isFavorite': False,
#   'publicationDate': '2025-09-10T00:00:00+02:00'},
#  {'country': 'Danmark',
#   'municipality': 'Aarhus',
#   'postalCode': 8000,
#   'postalDistrictName': 'Aarhus C',
#   'hiringOrgName': 'MFT Energy A/S',
#   'occupation': 'Datalog',
#   'conceptUriDa': 'http://data.star.dk/esco/occupation/12a6a59b-7a4e-4e2e-99d4-2d6c2dfd7bf8',
#   'workHourPartTime': False,
#   'jobAdId': 'E10721355',
#   'jobAdUrl': 'https://career.mft-energy.com/jobs/6120368-data-engineer',
#   'workPlaceAddress': 'Margrethepladsen 3, 4.',
#   'cvr': '38175130',
#   'title': 'Data Engineer - MFT Energy',
#   'description': 'Data Engineer - MFT Energy\n\n    \n\n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n\n\n\n    \n    \n    \n    \n    \n    \n    \n        \n        \n        \n\n        \n        \n        \n        \n      \n    \n    \n\n    \n  \n\n    \n\n  \n  \n\n  \n\n  \n    \n    \n\n\n\n      \n\n    \n\n      This website uses cookies to ensure you get the best experience.\n      \n\n        MFT Energy and our selected partners use cookies and similar technologies (together “cookies") that are necessary to present this website, and to ensure you get the best experience of it.\n\n          If you consent to it, we will also use cookies for analytics purposes.\n      \n\n\n      \nSee our Cookie Policy to read more about the cookies we set.\n\n      \nYou can withdraw and manage your consent at any time, by clicking “Manage cookies" at the bottom of each website page.\n\n\n\n    \n\n      Accept all cookies\n\n        Decline all non-necessary cookies\n\n      Cookie preferences\n    \n\n\n      \n  \n\n    Select which cookies you accept\n    \nOn this site, we always set cookies that are strictly necessary, meaning they are necessary for the site to function properly.\n\n    \nIf you consent to it, we will also set other types of cookies. You can provide or withdraw your consent to the different types of cookies using the toggles below. You can change or withdraw your consent at any time, by clicking the link “Manage Cookies", which is always available at the bottom of the site.\n\n    \nTo learn more about what the different types of cookies do, how your data is used when they are set etc, see our Cookie Policy.\n\n  \n\n\n  \n\n    \n\n  \n\n    \n    \n\n\n\n\n  \n\n    Strictly necessary\n    \nThese cookies are necessary to make the site work properly, and are always set when you visit the site.\n\n\n      \n        Vendors\n        Teamtailor\n      \n\n\n\n    \n\n  \n\n    \n    \n\n\n\n\n  \n\n    Analytics\n    \nThese cookies collect information to help us understand how the site is being used.\n\n\n      \n        Vendors\n        Teamtailor\n      \n\n\n\n    \n    \n  \n\n\n  \n\n    Accept these cookies\n    Decline all non-necessary cookies\n  \n\n\n\n\n\n    \n\n\n  \n    \n\n  \n\n            \n\n  \n    \n        \n        \n        \n        \n    \n    Career menu\n  \n  \n\n    \n      \n    \n    \n\n  \n\n\n\n\n\n\n\n\n\n  \n\n            \n\n  \n\n\n\n  \n          \n\n\n  \n\n\n\n\n\n  \n\n\n\n        \n\n\n    \n\n  \n\n    \n\n      \nTechnology\n\n  ·\n\n    Aarhus, Denmark\n\n\n    \n\n    Data Engineer\n    At MFT Energy, we innovate energy trading through our people and technology.\n\n      \n\n      \n    \n  \n    \n    Apply now!\n  \n\n\n\n\n\n\n\n\n  \n\n\n    \n      \n\n\n      \n  \n\n    Join a world of energy as MFT Energy\'s new Data Engineer\nIn MFT Energy we trade energy to make markets efficient and to facilitate the green transition. We are looking for a Data Engineer to join our ambitious Data Value team with experienced colleagues who strive to be the best every day.\nThe Job as Data Engineer\nAs our new Data Engineer, you will be part of a passionate Data Value team dedicated to making it easy, efficient, and enjoyable to work with data at MFT Energy. In this role, you will help design, develop, and maintain the data platforms that serve as the backbone of our trading operations. You will work closely with business and back-office teams, acting as an internal consultant to guide them in implementing new platforms and adopting data-driven practices. Beyond building systems, you will empower colleagues by facilitating internal courses, knowledge-sharing data communities, and introducing innovative tools and technologies.\n\nOur team of six brings together diverse expertise in data engineering, business intelligence, data science, and finance. Together, we thrive on curiosity, collaboration, and a shared commitment to exploring new technologies. The curren ...
#   'hasLogo': False,
#   'applicationDeadline': '1900-01-01T00:00:00+01:00',
#   'applicationDeadlineStatus': 'NotDisclosed',
#   'isSeen': False,
#   'isFavorite': False,
#   'publicationDate': '2025-08-27T00:00:00+02:00'},
#  {'country': 'Danmark',
#   'municipality': 'Aarhus',
#   'postalCode': 8520,
#   'postalDistrictName': 'Lystrup',
#   'hiringOrgName': 'Terma A/S',
#   'occupation': 'IT-ingeniør',
#   'conceptUriDa': 'http://data.star.dk/esco/occupation/93c9c217-48a0-4e70-9f1e-01a859665578',
#   'workHourPartTime': False,
#   'jobAdId': 'E10686244',
#   'jobAdUrl': 'https://termaas.hr-on.com/show-job/272243&locale=en_US',
#   'workPlaceAddress': 'Hovmarken 4',
#   'cvr': '41881828',
#   'title': 'Experienced Platform Engineer, DevSecOps, Lystrup - Terma A/S',
#   'description': "Experienced Platform Engineer, DevSecOps, Lystrup - Terma A/S\n        \n        \n        \n        \n\n        \n        \n\n        \n        \n        \n        \n        \n        \n        \n\n        \n\n        \n\n        \n        \n        \n        \n        \n        \n        \n        \n            \n            \n        \n\n\n\n    \n\n                    \n            \n\n\n\n\n\nExperienced Platform Engineer, DevSecOps, Lystrup\n\n\n\n\n    \n\n\n        \n\n            \nAt Terma, we develop advanced technologies and mission-critical systems that protect people on land, at sea, in the air, and in space. As we expand to meet new global challenges, we’re looking for an experienced Platform Engineer to help us evolve the infrastructure that powers secure, scalable, and high-impact software solutions across the defense and aerospace domains.\n\n\n\nYour role in our team \n\n\n\nAs part of our platform modernization journey, you'll play a key role in shaping the next generation of Terma’s internal developer platform - from tooling and architecture to deployment and DevSecOps practices. This is a hands-on engineering role where your contributions will directly impact developer experience and operational effectiveness across the company.\n\n\n\nYou will join a growing, collaborative DevSecOps team of six professionals known for their technical expertise, knowledge sharing, and good humour. Together, you'll enable dynamic development environments and modern CI/CD pipelines through automation, infrastructure-as-code, and security best practices.\n\n\n\nHow you will make a meaningful contribution \n\n\n\nYour key responsibilities include:\n\n\n\n\t\nDesign, build, and optimize core platform services to support secure development workflows\n\n\t\nAutomate provisioning of compliant developer environments and deployment pipelines\n\n\t\nMaintain and evolve the platform using tools such as Kubernetes, Ansible, GitLab, Jenkins, and SonarQube\n\n\t\nAdvocate for cloud-native and GitOps principles, driving best practices in automation and scaling\n\n\t\nHelp shape the future of our internal developer platform, contributing ideas, best practices, and architecture decisions\n\n\t\nContribute to team learning by sharing knowledge through documentation, code reviews, and learning sessions\n\n\n\n\nBring your world class expertise into play\n\n\n\nYou are fluent in English both in writing and verbal at a professional level. Danish is an advantage but not a requirement. Moreover, we are also looking for a new colleague with the following qualifications: \n\n\n\n\t\nStrong scripting skills in Python, Bash, and YAML\n\n\t\nHands-on knowledge of containerization (e.g., Docker, Podman)\n\n\t\nSolid understanding of CI/CD, DevSecOps, and GitOps methodologies\n\n\t\nProven experience with Infrastructure as Code and Configuration as Code practices (e.g., Terraform, Ansible, GitLab CI) and automation\n\n\t\nA cloud-native mindset, emphasizing scalability, resilience, and security\n\n\n\n\nPreferred but not required qualifications include: \n\n\n\n\t\nExperience designing or operating on-premise infrastructure and self-hosted systems (e.g., GitLab, Kubernetes)\n\n\t\nFamiliarity with tools such as Gerrit, Jenkins, Nexus, and SonarQube\n\n\t\nComfortable working in Linux-based environments, including shell scripting and troubleshooting\n\n\t\nBasic understanding of networking and system administration concepts (e.g., DNS, firewalls, certificates, reverse proxies)\n\n\t\nPrevious work in regulated or high-security environments\n\n\t\nBachelor’s degree in Computer Science, Engineering, or a related technical field\n\n\n\n\nPlease note: While we adopt a cloud-native approach, all infrastructure at Terma is hosted on-premise. We do not use public cloud providers (e.g., AWS, Azure), and familiarity with self-managed environments is a strong advantage.\n\n\n\nAs a person, you take initiative, own your work, and actively seek co ...
#   'hasLogo': False,
#   'applicationDeadline': '1910-01-01T00:00:00+01:00',
#   'applicationDeadlineStatus': 'AsSoonAsPossible',
#   'isSeen': False,
#   'isFavorite': False,
#   'publicationDate': '2025-07-24T00:00:00+02:00'}]

# %%
def jobnet_scraper(title, postal, km_dist, num_jobs, existing_keys: Optional[Set[Tuple[str,str]]] = None, cutoff_dt: Optional[datetime] = None):
    list_url = f"https://jobnet.dk/bff/FindJob/Search?resultsPerPage={num_jobs}&pageNumber=1&orderType=PublicationDate&kmRadius={km_dist}&searchString={title.replace(' ', '+')}&postalCode={postal}"
    response = requests.get(list_url)
    
    if response.status_code != 200:
        print(f"[scrape] Jobnet: failed to fetch job listings (status code: {response.status_code})")
        return pd.DataFrame(columns=['job_board'])
    response_dict = response.json()
    print(f"[scrape] Jobnet: fetching up to {num_jobs} jobs for '{title}' near {postal} {city} (r={km_dist}km)")
    if existing_keys is None:
        existing_keys = set()
    job_list = []
    postings = response_dict.get("JobPositionPostings", [])
    early_reason = None
    for job_dict in tqdm(postings, desc="Jobnet jobs", unit="job"):
        job_id = job_dict["ID"]
        job_url = job_dict["Url"]
        job_post = {}
        
        job_post["title"] = job_dict["Title"]
        job_post["company"] = job_dict["HiringOrgName"]
        job_post["location"] = job_dict["WorkPlaceCity"]
        
        job_post["time_posted"] = job_dict["PostingCreated"]
        job_post["url"] = job_url
        job_post["employment_type"] = job_dict["EmploymentType"]
        job_post["full_or_part_time"] = job_dict["WorkHours"]

        job_post["description"] = None 
        
        if not job_dict["IsExternal"]:
            job_response = requests.get(f"https://job.jobnet.dk/CV/FindWork/JobDetailJson?id={job_id}&previewtoken=")
            if job_response.status_code == 200:
                data = job_response.json()
                formatted_html = data.get("FormattedPurpose") or ""
                job_soup = BeautifulSoup(formatted_html, 'html.parser')
                desc_lines = [line.strip() for line in job_soup.stripped_strings if line.strip()]
                job_post["description"] = "\n".join(desc_lines) or data.get("Description")
        key = (job_post.get("company"), job_post.get("title"))
        # Early termination checks
        # Parse posted time if possible (ISO expected)
        posted_raw = job_post.get("time_posted")
        posted_dt = None
        if posted_raw:
            try:
                posted_dt = pd.to_datetime(posted_raw, utc=True, errors='coerce')
            except Exception:
                posted_dt = None
        if key in existing_keys:
            early_reason = "first existing key encountered (sorted list)"
            break
        if cutoff_dt and posted_dt is not None and posted_dt.to_pydatetime() < cutoff_dt:
            early_reason = "job older than last scrape timestamp"
            break
        job_list.append(job_post)

    df = pd.DataFrame(job_list)
    if not df.empty:
        df['job_board'] = 'jobnet'
    else:
        df = pd.DataFrame(columns=['job_board'])
    if early_reason:
        print(f"[scrape] Jobnet: early termination - {early_reason}; collected {len(job_list)} new rows")
    print(f"[scrape] Jobnet: dataframe rows={len(df)}")
    return df
